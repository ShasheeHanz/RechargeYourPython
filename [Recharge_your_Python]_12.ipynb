# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshanJayawardana/RechargeYourPython/blob/main/%5BRecharge_your_Python%5D_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pandas as pd
import os
 
 

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)


folder_path = '/content/drive/MyDrive/Folder12-20230328T094652Z-001/Folder12'

# %% [markdown]
# # Task 1

# %%
def count_folders(path):
    count = 0
    for _, dirs, files in os.walk(path):
        count += len(dirs)
        print(dirs)
    return count

# %%
num_folders = count_folders(folder_path)
print("Number of folders: {}".format( num_folders))
# Out:
# ['v03', 'v02', 'v01', 'v04']
# ['run34', 'run31', 'run32', 'run33']
# []
# []
# []
# []
# ['run21', 'run22']
# []
# []
# ['run12', 'run13', 'run11']
# []
# []
# []
# ['run41', 'run42']
# []
# []
# Number of folders: 15

# %% [markdown]
# # Task 2

# %%
def nuof_csv_files(path):
    count = 0
    
    for root, dirs, files in os.walk(path):
        for filename in files:
            if filename.endswith(".csv"):
                print(filename)
                count += 1
    print(files)
    return count

# %%
num_csv_files = nuof_csv_files(folder_path)
print("Number of CSV files: {}".format(num_csv_files))
# Out:
# t150.csv
# t143.csv
# t142.csv
# t144.csv
# t147.csv
# t145.csv
# t146.csv
# t148.csv
# t149.csv
# t156.csv
# t155.csv
# t153.csv
# t154.csv
# t152.csv
# t151.csv
# t133.csv
# t132.csv
# t157.csv
# t131.csv
# t134.csv
# t140.csv
# t138.csv
# t139.csv
# t141.csv
# t137.csv
# t136.csv
# t135.csv
# ['t137.csv', 't136.csv', 't135.csv']
# Number of CSV files: 27

# %% [markdown]
# # Task 3

# %%
def find_largest_csv_file_size(path):
    max_size = 100000
    for root, dirs, filenames in os.walk(path):
        for filename in filenames:
            if filename.endswith(".csv"):
                file_path = os.path.join(root, filename)
                size = os.path.getsize(file_path)
                if size < max_size:
                    max_size = size
    return max_size

# %%
largest_csv_size = find_largest_csv_file_size(folder_path)
print("Size in bytes of the largest CSV file: {}".format(largest_csv_size))
# Out:
# Size in bytes of the largest CSV file: 22

# %%
def find_largest_csv_file_size(path):
    min_size
    for root, dirs, filenames in os.walk(path):
        for filename in filenames:
            if filename.endswith(".csv"):
                file_path = os.path.join(root, filename)
                size = os.path.getsize(file_path)
                if size < min_size:
                    min_size = size
    return min_size

# %%
largest_csv_size = find_largest_csv_file_size(folder_path)
print("Size in bytes of the largest CSV file: {}".format(largest_csv_size))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-20-a1f3728ee3bd> in <module>
# ----> 1 largest_csv_size = find_largest_csv_file_size(folder_path)
#       2 print("Size in bytes of the largest CSV file: {}".format(largest_csv_size))
#
# <ipython-input-19-dbc008486379> in find_largest_csv_file_size(path)
#       1 def find_largest_csv_file_size(path):
# ----> 2     min_size
#       3     for root, dirs, filenames in os.walk(path):
#       4         for filename in filenames:
#       5             if filename.endswith(".csv"):
#
# UnboundLocalError: local variable 'min_size' referenced before assignment
